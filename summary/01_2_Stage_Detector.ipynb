# %% [markdown]
# # 2-Stage Detector

# %% [markdown]
# ### 특징
# 1) Localization(후보 영역 찾기)
# 2) Classification(후보 영역에 대한 분류)
#
# - Limitation: 속도가 느림

# %% [markdown]
# ![image.png](attachment:e55f7268-6bba-438d-b696-3c5c74ef95be.png)
